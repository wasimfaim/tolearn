# %% [markdown]
# <a href="https://colab.research.google.com/github/wasimfaim/tolearn/blob/main/Hacker_Rank_SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * SQL ANSI American National Standard institute
# * DDL -Data defonition language
# CREAT DROP TRUNCATE ALTER RENAME
# * DML - Data Manipulation Language
# INSERT UPDATE DELETE
#
# * DQL - Data Querry Language  SELECT
# * DCL - Data Control Language GRANT REVOKE
# * TCL - Transaction Controle Language COMMIT ROLLBAC SAVE POINT

# %% [markdown]
# **1**
# ![Screenshot (584).png](data:image/png;base64,...)

# %% [markdown]
# Total no. of record - NO. of unique city names = 3-2 = 1
